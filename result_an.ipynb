# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cbench-automotive-susan-c-result.csv')
df['result_list']
# Out:
# 0      {'best_result': 24352, 'generations': 0}
# 1      {'best_result': 24888, 'generations': 1}
# 2      {'best_result': 23890, 'generations': 2}
# 3      {'best_result': 24044, 'generations': 3}
# 4      {'best_result': 24350, 'generations': 4}
# 5      {'best_result': 24434, 'generations': 5}
# 6      {'best_result': 24494, 'generations': 6}
# 7      {'best_result': 23550, 'generations': 7}
# 8      {'best_result': 23550, 'generations': 8}
# 9      {'best_result': 23550, 'generations': 9}
# 10    {'best_result': 23514, 'generations': 10}
# 11    {'best_result': 23462, 'generations': 11}
# 12    {'best_result': 23462, 'generations': 12}
# 13    {'best_result': 23462, 'generations': 13}
# 14    {'best_result': 23462, 'generations': 14}
# 15    {'best_result': 23462, 'generations': 15}
# 16    {'best_result': 23434, 'generations': 16}
# 17    {'best_result': 23434, 'generations': 17}
# 18    {'best_result': 23434, 'generations': 18}
# 19    {'best_result': 23430, 'generations': 19}
# ...

# %%
df = pd.read_csv('cbench-automotive-susan-c-result2.csv')
# result = df['result_list']
# result_dict = eval(result.values[0])
r = []
for i in df['result_list']:
    tmp = eval(i)
    r.append(int(tmp['best_result']))
print(min(r))
plt.title('compile size of cbench-automotive-susan')
plt.ylabel('size')
plt.xlabel('generation')
plt.plot(r)
plt.savefig('agentga.png')
# result.values
# Out:
# 23184
